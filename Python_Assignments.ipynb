# %% [markdown]
# Question 1: -
# Write a program that takes a string as input, and counts the frequency of each word in the string, there might
# be repeated characters in the string. Your task is to find the highest frequency and returns the length of the
# highest-frequency word.

# %%
s=str(input("Enter a sentence:"))
a=s.split()
dict = {}
for word in a:
    dict[word] = dict.get(word, 0) + 1
max_val = max(dict.values())
max_words = [word for word, frequency in dict.items() if frequency == max_val]
max_words_len = [len(word) for word in max_words]
max_words_len[0]
# Out:
# Enter a sentence:“write write write all the number from from from 1 to 100 write write write
# 5

# %% [markdown]
# Question 2: -
# Consider a string to be valid if all characters of the string appear the same number of times. It is also valid if
# he can remove just one character at the index in the string, and the remaining characters will occur the same
# number of times. Given a string, determine if it is valid. If so, return YES , otherwise return NO

# %%
s = input("Enter a string: ")
counts = {}
for char in s:
    counts[char] =counts.get(char, 0) + 1

counts = list(char_counts.values())

if len(set(counts)) == 1:
    print("YES")
elif len(set(counts)) == 2 and (counts.count(counts[0]) == 1 or counts.count(counts[1]) == 1) and abs(counts[0] - counts[1]) == 1:
    print("YES")
else:
    print("NO")
# Out:
# Enter a string: abcc
# NO

# %% [markdown]
# Question 3: -
# Write a program, which would download the data from the provided link, and then read the data and convert
# that into properly structured data and return it in Excel format.

# %%
import pandas as pd
import requests

# Download the data from the provided link
url = "https://raw.githubusercontent.com/Biuni/PokemonGO-Pokedex/master/pokedex.json"
response = requests.get(url)
data = response.json()

# Extract relevant information from the JSON data
pokemon_list = data["pokemon"]
pokemon_data = []
all_columns = set()

for pokemon in pokemon_list:
    pokemon_info = []
    for key, value in pokemon.items():
        if isinstance(value, (str, int, float)):
            pokemon_info.append((key,value, type(value)))
            all_columns.add(key)
    pokemon_data.append(pokemon_info)
pokemon_data[0]
# Out:
# [('id', 1, int),
#  ('num', '001', str),
#  ('name', 'Bulbasaur', str),
#  ('img', 'http://www.serebii.net/pokemongo/pokemon/001.png', str),
#  ('height', '0.71 m', str),
#  ('weight', '6.9 kg', str),
#  ('candy', 'Bulbasaur Candy', str),
#  ('candy_count', 25, int),
#  ('egg', '2 km', str),
#  ('spawn_chance', 0.69, float),
#  ('avg_spawns', 69, int),
#  ('spawn_time', '20:00', str)]

# %% [markdown]
# Question 4 -
# Write a program to download the data from the link given below and then read the data and convert the into
# the proper structure and return it as a CSV file.
# Link - https://data.nasa.gov/resource/y77d-th95.json

# %%
import pandas as pd
import requests
url = "https://data.nasa.gov/resource/y77d-th95.json" 
response = requests.get(url)
data = response.json()
pokemon_data = []
all_columns = set()

for pokemon in data:
    pokemon_info = []
    for key, value in pokemon.items():
        if isinstance(value, (str, int, float)):
            pokemon_info.append((key,value, type(value).__name__))
            all_columns.add(key)
    pokemon_data.append(pokemon_info)
pokemon_data[0]
# Out:
# [('name', 'Aachen', 'str'),
#  ('id', '1', 'str'),
#  ('nametype', 'Valid', 'str'),
#  ('recclass', 'L5', 'str'),
#  ('mass', '21', 'str'),
#  ('fall', 'Fell', 'str'),
#  ('year', '1880-01-01T00:00:00.000', 'str'),
#  ('reclat', '50.775000', 'str'),
#  ('reclong', '6.083330', 'str')]

# %%
Question 5 -
Write a program to download the data from the given API link and then extract the following data with
proper formatting

# %%
import requests
import pandas as pd
from pandas.io.json import json_normalize

# Download data from the API
url = "http://api.tvmaze.com/singlesearch/shows?q=westworld&embed=episodes"
response = requests.get(url)
data = response.json()

## Flatten the JSON data and create a DataFrame
df = json_normalize(data)

# Display the extracted data
print(df.columns,df.dtypes)
# Out:
# Index(['id', 'url', 'name', 'type', 'language', 'genres', 'status', 'runtime',
#        'averageRuntime', 'premiered', 'ended', 'officialSite', 'weight',
#        'webChannel', 'dvdCountry', 'summary', 'updated', 'schedule.time',
#        'schedule.days', 'rating.average', 'network.id', 'network.name',
#        'network.country.name', 'network.country.code',
#        'network.country.timezone', 'network.officialSite', 'externals.tvrage',
#        'externals.thetvdb', 'externals.imdb', 'image.medium', 'image.original',
#        '_links.self.href', '_links.previousepisode.href',
#        '_embedded.episodes'],
#       dtype='object') id                               int64
# url                             object
# name                            object
# type                            object
# language                        object
# genres                          object
# status                          object
# runtime                          int64
# averageRuntime                   int64
# premiered                       object
# ended                           object
# officialSite                    object
# weight                           int64
# webChannel                      object
# dvdCountry                      object
# summary                         object
# updated                          int64
# schedule.time                   object
# schedule.days                   object
# rating.average                 float64
# network.id                       int64
# network.name                    object
# network.country.name            object
# network.country.code            object
# network.country.timezone        object
# network.officialSite            object
# externals.tvrage                 int64
# externals.thetvdb                int64
# externals.imdb                  object
# image.medium                    object
# image.original                  object
# _links.self.href                object
# _links.previousepisode.href     object
# _embedded.episodes              object
# dtype: object
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\3068412254.py:11: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   df = json_normalize(data)

# %%
Question 6 -

Using the data from Question 3, write code to analyze the data and answer the following questions Note 1.
Draw plots to demonstrate the analysis for the following questions for better visualizations.
2. Write code comments wherever required for code understanding

# %%
import pandas as pd
import requests

# Download the data from the provided link
url = "https://raw.githubusercontent.com/Biuni/PokemonGO-Pokedex/master/pokedex.json"
response = requests.get(url)
data = response.json()

# Extract all columns from the JSON data
all_columns = set()
for pokemon in data["pokemon"]:
    all_columns.update(pokemon.keys())

# Create an empty DataFrame with the extracted columns
df = pd.DataFrame(columns=all_columns)

# Iterate over the JSON data and populate the DataFrame
for pokemon in data["pokemon"]:
    df = df.append(pokemon, ignore_index=True)

# Save the DataFrame as a CSV file
output_file = "pokemon_data.csv"
df.to_csv(output_file, index=False)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\1845465954.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pokemon, ignore_index=True)

# %%
df
# Out:
#              egg avg_spawns  \
# 0           2 km         69
# 1    Not in Eggs        4.2
# 2    Not in Eggs        1.7
# 3           2 km       25.3
# 4    Not in Eggs        1.2
# ..           ...        ...
# 146        10 km         30
# 147  Not in Eggs          2
# 148  Not in Eggs       0.11
# 149  Not in Eggs          0
# 150  Not in Eggs          0
#
#                                         next_evolution  num  height  \
# 0    [{'num': '002', 'name': 'Ivysaur'}, {'num': '0...  001  0.71 m
# 1                 [{'num': '003', 'name': 'Venusaur'}]  002  0.99 m
# 2                                                  NaN  003  2.01 m
# 3    [{'num': '005', 'name': 'Charmeleon'}, {'num':...  004  0.61 m
# 4                [{'num': '006', 'name': 'Charizard'}]  005  1.09 m
# ..                                                 ...  ...     ...
# 146  [{'num': '148', 'name': 'Dragonair'}, {'num': ...  147  1.80 m
# 147              [{'num': '149', 'name': 'Dragonite'}]  148  3.99 m
# 148                                                NaN  149  2.21 m
# 149                                                NaN  150  2.01 m
# 150                                                NaN  151  0.41 m
#
#     spawn_chance spawn_time              type   multipliers candy_count   id  \
# 0           0.69      20:00   [Grass, Poison]        [1.58]          25    1
# 1          0.042      07:00   [Grass, Poison]    [1.2, 1.6]         100    2
# 2          0.017      11:30   [Grass, Poison]          None         NaN    3
# 3          0.253      08:45            [Fire]        [1.65]          25    4
# 4          0.012      19:00            [Fire]        [1.79]         100    5
# ..           ...        ...               ...           ...         ...  ...
# 146          0.3      06:41          [Dragon]  [1.83, 1.84]          25  147
# 147         0.02      11:57          [Dragon]        [2.05]         100  148
# 148       0.0011      23:38  [Dragon, Flying]          None         NaN  149
# 149            0        N/A         [Psychic]          None         NaN  150
# 150            0        N/A         [Psychic]          None         NaN  151
#
#                                         prev_evolution  \
# 0                                                  NaN
# 1                [{'num': '001', 'name': 'Bulbasaur'}]
# 2    [{'num': '001', 'name': 'Bulbasaur'}, {'num': ...
# 3                                                  NaN
# 4               [{'num': '004', 'name': 'Charmander'}]
# ..                                                 ...
# 146                                                NaN
# 147                [{'num': '147', 'name': 'Dratini'}]
# 148  [{'num': '147', 'name': 'Dratini'}, {'num': '1...
# 149                                                NaN
# 150                                                NaN
#
#                                                   img        name    weight  \
# 0    http://www.serebii.net/pokemongo/pokemon/001.png   Bulbasaur    6.9 kg
# 1    http://www.serebii.net/pokemongo/pokemon/002.png     Ivysaur   13.0 kg
# 2    http://www.serebii.net/pokemongo/pokemon/003.png    Venusaur  100.0 kg
# 3    http://www.serebii.net/pokemongo/pokemon/004.png  Charmander    8.5 kg
# 4    http://www.serebii.net/pokemongo/pokemon/005.png  Charmeleon   19.0 kg
# ..                                                ...         ...       ...
# 146  http://www.serebii.net/pokemongo/pokemon/147.png     Dratini    3.3 kg
# 147  http://www.serebii.net/pokemongo/pokemon/148.png   Dragonair   16.5 kg
# 148  http://www.serebii.net/pokemongo/pokemon/149.png   Dragonite  210.0 kg
# 149  http://www.serebii.net/pokemongo/pokemon/150.png      Mewtwo  122.0 kg
# 150  http://www.serebii.net/pokemongo/pokemon/151.png         Mew    4.0 kg
#
#                        weaknesses             candy
# 0    [Fire, Ice, Flying, Psychic]   Bulbasaur Candy
# 1    [Fire, Ice, Flying, Psychic]   Bulbasaur Candy
# 2    [Fire, Ice, Flying, Psychic]   Bulbasaur Candy
# 3           [Water, Ground, Rock]  Charmander Candy
# 4           [Water, Ground, Rock]  Charmander Candy
# ..                            ...               ...
# 146          [Ice, Dragon, Fairy]     Dratini Candy
# 147          [Ice, Dragon, Fairy]     Dratini Candy
# 148    [Ice, Rock, Dragon, Fairy]     Dratini Candy
# 149            [Bug, Ghost, Dark]              None
# 150            [Bug, Ghost, Dark]              None
#
# [151 rows x 17 columns]

# %% [markdown]
# ● Get all Pokemons whose spawn rate is less than 5%
# ● Get all Pokemons that have less than 4 weaknesses
# ● Get all Pokemons that have no multipliers at all
# ● Get all Pokemons that do not have more than 2 evolutions
# ● Get all Pokemons whose spawn time is less than 300 seconds.

# %%
#Q.1
df[df['spawn_chance']<5.0]
# Out:
#              egg avg_spawns  \
# 0           2 km         69
# 1    Not in Eggs        4.2
# 2    Not in Eggs        1.7
# 3           2 km       25.3
# 4    Not in Eggs        1.2
# ..           ...        ...
# 146        10 km         30
# 147  Not in Eggs          2
# 148  Not in Eggs       0.11
# 149  Not in Eggs          0
# 150  Not in Eggs          0
#
#                                         next_evolution  num  height  \
# 0    [{'num': '002', 'name': 'Ivysaur'}, {'num': '0...  001  0.71 m
# 1                 [{'num': '003', 'name': 'Venusaur'}]  002  0.99 m
# 2                                                  NaN  003  2.01 m
# 3    [{'num': '005', 'name': 'Charmeleon'}, {'num':...  004  0.61 m
# 4                [{'num': '006', 'name': 'Charizard'}]  005  1.09 m
# ..                                                 ...  ...     ...
# 146  [{'num': '148', 'name': 'Dragonair'}, {'num': ...  147  1.80 m
# 147              [{'num': '149', 'name': 'Dragonite'}]  148  3.99 m
# 148                                                NaN  149  2.21 m
# 149                                                NaN  150  2.01 m
# 150                                                NaN  151  0.41 m
#
#     spawn_chance spawn_time              type   multipliers candy_count   id  \
# 0           0.69      20:00   [Grass, Poison]        [1.58]          25    1
# 1          0.042      07:00   [Grass, Poison]    [1.2, 1.6]         100    2
# 2          0.017      11:30   [Grass, Poison]          None         NaN    3
# 3          0.253      08:45            [Fire]        [1.65]          25    4
# 4          0.012      19:00            [Fire]        [1.79]         100    5
# ..           ...        ...               ...           ...         ...  ...
# 146          0.3      06:41          [Dragon]  [1.83, 1.84]          25  147
# 147         0.02      11:57          [Dragon]        [2.05]         100  148
# 148       0.0011      23:38  [Dragon, Flying]          None         NaN  149
# 149            0        N/A         [Psychic]          None         NaN  150
# 150            0        N/A         [Psychic]          None         NaN  151
#
#                                         prev_evolution  \
# 0                                                  NaN
# 1                [{'num': '001', 'name': 'Bulbasaur'}]
# 2    [{'num': '001', 'name': 'Bulbasaur'}, {'num': ...
# 3                                                  NaN
# 4               [{'num': '004', 'name': 'Charmander'}]
# ..                                                 ...
# 146                                                NaN
# 147                [{'num': '147', 'name': 'Dratini'}]
# 148  [{'num': '147', 'name': 'Dratini'}, {'num': '1...
# 149                                                NaN
# 150                                                NaN
#
#                                                   img        name    weight  \
# 0    http://www.serebii.net/pokemongo/pokemon/001.png   Bulbasaur    6.9 kg
# 1    http://www.serebii.net/pokemongo/pokemon/002.png     Ivysaur   13.0 kg
# 2    http://www.serebii.net/pokemongo/pokemon/003.png    Venusaur  100.0 kg
# 3    http://www.serebii.net/pokemongo/pokemon/004.png  Charmander    8.5 kg
# 4    http://www.serebii.net/pokemongo/pokemon/005.png  Charmeleon   19.0 kg
# ..                                                ...         ...       ...
# 146  http://www.serebii.net/pokemongo/pokemon/147.png     Dratini    3.3 kg
# 147  http://www.serebii.net/pokemongo/pokemon/148.png   Dragonair   16.5 kg
# 148  http://www.serebii.net/pokemongo/pokemon/149.png   Dragonite  210.0 kg
# 149  http://www.serebii.net/pokemongo/pokemon/150.png      Mewtwo  122.0 kg
# 150  http://www.serebii.net/pokemongo/pokemon/151.png         Mew    4.0 kg
#
#                        weaknesses             candy
# 0    [Fire, Ice, Flying, Psychic]   Bulbasaur Candy
# 1    [Fire, Ice, Flying, Psychic]   Bulbasaur Candy
# 2    [Fire, Ice, Flying, Psychic]   Bulbasaur Candy
# 3           [Water, Ground, Rock]  Charmander Candy
# 4           [Water, Ground, Rock]  Charmander Candy
# ..                            ...               ...
# 146          [Ice, Dragon, Fairy]     Dratini Candy
# 147          [Ice, Dragon, Fairy]     Dratini Candy
# 148    [Ice, Rock, Dragon, Fairy]     Dratini Candy
# 149            [Bug, Ghost, Dark]              None
# 150            [Bug, Ghost, Dark]              None
#
# [147 rows x 17 columns]

# %%
#Q.2
df[df['weaknesses'].apply(len) < 4]
# Out:
#              egg avg_spawns  \
# 3           2 km       25.3
# 4    Not in Eggs        1.2
# 5    Not in Eggs       0.31
# 6           2 km         58
# 7    Not in Eggs        3.4
# ..           ...        ...
# 145  Not in Eggs          0
# 146        10 km         30
# 147  Not in Eggs          2
# 149  Not in Eggs          0
# 150  Not in Eggs          0
#
#                                         next_evolution  num  height  \
# 3    [{'num': '005', 'name': 'Charmeleon'}, {'num':...  004  0.61 m
# 4                [{'num': '006', 'name': 'Charizard'}]  005  1.09 m
# 5                                                  NaN  006  1.70 m
# 6    [{'num': '008', 'name': 'Wartortle'}, {'num': ...  007  0.51 m
# 7                [{'num': '009', 'name': 'Blastoise'}]  008  0.99 m
# ..                                                 ...  ...     ...
# 145                                                NaN  146  2.01 m
# 146  [{'num': '148', 'name': 'Dragonair'}, {'num': ...  147  1.80 m
# 147              [{'num': '149', 'name': 'Dragonite'}]  148  3.99 m
# 149                                                NaN  150  2.01 m
# 150                                                NaN  151  0.41 m
#
#     spawn_chance spawn_time            type   multipliers candy_count   id  \
# 3          0.253      08:45          [Fire]        [1.65]          25    4
# 4          0.012      19:00          [Fire]        [1.79]         100    5
# 5         0.0031      13:34  [Fire, Flying]          None         NaN    6
# 6           0.58      04:25         [Water]         [2.1]          25    7
# 7          0.034      07:02         [Water]         [1.4]         100    8
# ..           ...        ...             ...           ...         ...  ...
# 145            0        N/A  [Fire, Flying]          None         NaN  146
# 146          0.3      06:41        [Dragon]  [1.83, 1.84]          25  147
# 147         0.02      11:57        [Dragon]        [2.05]         100  148
# 149            0        N/A       [Psychic]          None         NaN  150
# 150            0        N/A       [Psychic]          None         NaN  151
#
#                                         prev_evolution  \
# 3                                                  NaN
# 4               [{'num': '004', 'name': 'Charmander'}]
# 5    [{'num': '004', 'name': 'Charmander'}, {'num':...
# 6                                                  NaN
# 7                 [{'num': '007', 'name': 'Squirtle'}]
# ..                                                 ...
# 145                                                NaN
# 146                                                NaN
# 147                [{'num': '147', 'name': 'Dratini'}]
# 149                                                NaN
# 150                                                NaN
#
#                                                   img        name    weight  \
# 3    http://www.serebii.net/pokemongo/pokemon/004.png  Charmander    8.5 kg
# 4    http://www.serebii.net/pokemongo/pokemon/005.png  Charmeleon   19.0 kg
# 5    http://www.serebii.net/pokemongo/pokemon/006.png   Charizard   90.5 kg
# 6    http://www.serebii.net/pokemongo/pokemon/007.png    Squirtle    9.0 kg
# 7    http://www.serebii.net/pokemongo/pokemon/008.png   Wartortle   22.5 kg
# ..                                                ...         ...       ...
# 145  http://www.serebii.net/pokemongo/pokemon/146.png     Moltres   60.0 kg
# 146  http://www.serebii.net/pokemongo/pokemon/147.png     Dratini    3.3 kg
# 147  http://www.serebii.net/pokemongo/pokemon/148.png   Dragonair   16.5 kg
# 149  http://www.serebii.net/pokemongo/pokemon/150.png      Mewtwo  122.0 kg
# 150  http://www.serebii.net/pokemongo/pokemon/151.png         Mew    4.0 kg
#
#                   weaknesses             candy
# 3      [Water, Ground, Rock]  Charmander Candy
# 4      [Water, Ground, Rock]  Charmander Candy
# 5    [Water, Electric, Rock]  Charmander Candy
# 6          [Electric, Grass]    Squirtle Candy
# 7          [Electric, Grass]    Squirtle Candy
# ..                       ...               ...
# 145  [Water, Electric, Rock]              None
# 146     [Ice, Dragon, Fairy]     Dratini Candy
# 147     [Ice, Dragon, Fairy]     Dratini Candy
# 149       [Bug, Ghost, Dark]              None
# 150       [Bug, Ghost, Dark]              None
#
# [102 rows x 17 columns]

# %%
#Q.3
df[df['multipliers'].isna()]
# Out:
#              egg avg_spawns next_evolution  num  height spawn_chance  \
# 2    Not in Eggs        1.7            NaN  003  2.01 m        0.017
# 5    Not in Eggs       0.31            NaN  006  1.70 m       0.0031
# 8    Not in Eggs       0.67            NaN  009  1.60 m       0.0067
# 11   Not in Eggs        2.2            NaN  012  1.09 m        0.022
# 14   Not in Eggs        5.1            NaN  015  0.99 m        0.051
# ..           ...        ...            ...  ...     ...          ...
# 144  Not in Eggs          0            NaN  145  1.60 m            0
# 145  Not in Eggs          0            NaN  146  2.01 m            0
# 148  Not in Eggs       0.11            NaN  149  2.21 m       0.0011
# 149  Not in Eggs          0            NaN  150  2.01 m            0
# 150  Not in Eggs          0            NaN  151  0.41 m            0
#
#     spawn_time                type multipliers candy_count   id  \
# 2        11:30     [Grass, Poison]        None         NaN    3
# 5        13:34      [Fire, Flying]        None         NaN    6
# 8        00:06             [Water]        None         NaN    9
# 11       05:23       [Bug, Flying]        None         NaN   12
# 14       04:50       [Bug, Poison]        None         NaN   15
# ..         ...                 ...         ...         ...  ...
# 144        N/A  [Electric, Flying]        None         NaN  145
# 145        N/A      [Fire, Flying]        None         NaN  146
# 148      23:38    [Dragon, Flying]        None         NaN  149
# 149        N/A           [Psychic]        None         NaN  150
# 150        N/A           [Psychic]        None         NaN  151
#
#                                         prev_evolution  \
# 2    [{'num': '001', 'name': 'Bulbasaur'}, {'num': ...
# 5    [{'num': '004', 'name': 'Charmander'}, {'num':...
# 8    [{'num': '007', 'name': 'Squirtle'}, {'num': '...
# 11   [{'num': '010', 'name': 'Caterpie'}, {'num': '...
# 14   [{'num': '013', 'name': 'Weedle'}, {'num': '01...
# ..                                                 ...
# 144                                                NaN
# 145                                                NaN
# 148  [{'num': '147', 'name': 'Dratini'}, {'num': '1...
# 149                                                NaN
# 150                                                NaN
#
#                                                   img        name    weight  \
# 2    http://www.serebii.net/pokemongo/pokemon/003.png    Venusaur  100.0 kg
# 5    http://www.serebii.net/pokemongo/pokemon/006.png   Charizard   90.5 kg
# 8    http://www.serebii.net/pokemongo/pokemon/009.png   Blastoise   85.5 kg
# 11   http://www.serebii.net/pokemongo/pokemon/012.png  Butterfree   32.0 kg
# 14   http://www.serebii.net/pokemongo/pokemon/015.png    Beedrill   29.5 kg
# ..                                                ...         ...       ...
# 144  http://www.serebii.net/pokemongo/pokemon/145.png      Zapdos   52.6 kg
# 145  http://www.serebii.net/pokemongo/pokemon/146.png     Moltres   60.0 kg
# 148  http://www.serebii.net/pokemongo/pokemon/149.png   Dragonite  210.0 kg
# 149  http://www.serebii.net/pokemongo/pokemon/150.png      Mewtwo  122.0 kg
# 150  http://www.serebii.net/pokemongo/pokemon/151.png         Mew    4.0 kg
#
#                               weaknesses             candy
# 2           [Fire, Ice, Flying, Psychic]   Bulbasaur Candy
# 5                [Water, Electric, Rock]  Charmander Candy
# 8                      [Electric, Grass]    Squirtle Candy
# 11   [Fire, Electric, Ice, Flying, Rock]    Caterpie Candy
# 14         [Fire, Flying, Psychic, Rock]      Weedle Candy
# ..                                   ...               ...
# 144                          [Ice, Rock]              None
# 145              [Water, Electric, Rock]              None
# 148           [Ice, Rock, Dragon, Fairy]     Dratini Candy
# 149                   [Bug, Ghost, Dark]              None
# 150                   [Bug, Ghost, Dark]              None
#
# [81 rows x 17 columns]

# %%
#Q.4
df[df['prev_evolution'].apply(lambda x: len(x) <= 2 if isinstance(x, list) else True)]
# Out:
#              egg avg_spawns  \
# 0           2 km         69
# 1    Not in Eggs        4.2
# 2    Not in Eggs        1.7
# 3           2 km       25.3
# 4    Not in Eggs        1.2
# ..           ...        ...
# 146        10 km         30
# 147  Not in Eggs          2
# 148  Not in Eggs       0.11
# 149  Not in Eggs          0
# 150  Not in Eggs          0
#
#                                         next_evolution  num  height  \
# 0    [{'num': '002', 'name': 'Ivysaur'}, {'num': '0...  001  0.71 m
# 1                 [{'num': '003', 'name': 'Venusaur'}]  002  0.99 m
# 2                                                  NaN  003  2.01 m
# 3    [{'num': '005', 'name': 'Charmeleon'}, {'num':...  004  0.61 m
# 4                [{'num': '006', 'name': 'Charizard'}]  005  1.09 m
# ..                                                 ...  ...     ...
# 146  [{'num': '148', 'name': 'Dragonair'}, {'num': ...  147  1.80 m
# 147              [{'num': '149', 'name': 'Dragonite'}]  148  3.99 m
# 148                                                NaN  149  2.21 m
# 149                                                NaN  150  2.01 m
# 150                                                NaN  151  0.41 m
#
#     spawn_chance spawn_time              type   multipliers candy_count   id  \
# 0           0.69      20:00   [Grass, Poison]        [1.58]          25    1
# 1          0.042      07:00   [Grass, Poison]    [1.2, 1.6]         100    2
# 2          0.017      11:30   [Grass, Poison]          None         NaN    3
# 3          0.253      08:45            [Fire]        [1.65]          25    4
# 4          0.012      19:00            [Fire]        [1.79]         100    5
# ..           ...        ...               ...           ...         ...  ...
# 146          0.3      06:41          [Dragon]  [1.83, 1.84]          25  147
# 147         0.02      11:57          [Dragon]        [2.05]         100  148
# 148       0.0011      23:38  [Dragon, Flying]          None         NaN  149
# 149            0        N/A         [Psychic]          None         NaN  150
# 150            0        N/A         [Psychic]          None         NaN  151
#
#                                         prev_evolution  \
# 0                                                  NaN
# 1                [{'num': '001', 'name': 'Bulbasaur'}]
# 2    [{'num': '001', 'name': 'Bulbasaur'}, {'num': ...
# 3                                                  NaN
# 4               [{'num': '004', 'name': 'Charmander'}]
# ..                                                 ...
# 146                                                NaN
# 147                [{'num': '147', 'name': 'Dratini'}]
# 148  [{'num': '147', 'name': 'Dratini'}, {'num': '1...
# 149                                                NaN
# 150                                                NaN
#
#                                                   img        name    weight  \
# 0    http://www.serebii.net/pokemongo/pokemon/001.png   Bulbasaur    6.9 kg
# 1    http://www.serebii.net/pokemongo/pokemon/002.png     Ivysaur   13.0 kg
# 2    http://www.serebii.net/pokemongo/pokemon/003.png    Venusaur  100.0 kg
# 3    http://www.serebii.net/pokemongo/pokemon/004.png  Charmander    8.5 kg
# 4    http://www.serebii.net/pokemongo/pokemon/005.png  Charmeleon   19.0 kg
# ..                                                ...         ...       ...
# 146  http://www.serebii.net/pokemongo/pokemon/147.png     Dratini    3.3 kg
# 147  http://www.serebii.net/pokemongo/pokemon/148.png   Dragonair   16.5 kg
# 148  http://www.serebii.net/pokemongo/pokemon/149.png   Dragonite  210.0 kg
# 149  http://www.serebii.net/pokemongo/pokemon/150.png      Mewtwo  122.0 kg
# 150  http://www.serebii.net/pokemongo/pokemon/151.png         Mew    4.0 kg
#
#                        weaknesses             candy
# 0    [Fire, Ice, Flying, Psychic]   Bulbasaur Candy
# 1    [Fire, Ice, Flying, Psychic]   Bulbasaur Candy
# 2    [Fire, Ice, Flying, Psychic]   Bulbasaur Candy
# 3           [Water, Ground, Rock]  Charmander Candy
# 4           [Water, Ground, Rock]  Charmander Candy
# ..                            ...               ...
# 146          [Ice, Dragon, Fairy]     Dratini Candy
# 147          [Ice, Dragon, Fairy]     Dratini Candy
# 148    [Ice, Rock, Dragon, Fairy]     Dratini Candy
# 149            [Bug, Ghost, Dark]              None
# 150            [Bug, Ghost, Dark]              None
#
# [151 rows x 17 columns]

# %%
#Q.5
df[df['spawn_time']< '00:30']
# Out:
#              egg avg_spawns                        next_evolution  num  \
# 8    Not in Eggs       0.67                                   NaN  009
# 92   Not in Eggs        5.2    [{'num': '094', 'name': 'Gengar'}]  093
# 139        10 km         10  [{'num': '141', 'name': 'Kabutops'}]  140
#
#      height spawn_chance spawn_time             type   multipliers  \
# 8    1.60 m       0.0067      00:06          [Water]          None
# 92   1.60 m        0.052      00:10  [Ghost, Poison]   [1.56, 1.8]
# 139  0.51 m          0.1      00:05    [Rock, Water]  [1.97, 2.37]
#
#     candy_count   id                                     prev_evolution  \
# 8           NaN    9  [{'num': '007', 'name': 'Squirtle'}, {'num': '...
# 92          100   93                 [{'num': '092', 'name': 'Gastly'}]
# 139          50  140                                                NaN
#
#                                                   img       name   weight  \
# 8    http://www.serebii.net/pokemongo/pokemon/009.png  Blastoise  85.5 kg
# 92   http://www.serebii.net/pokemongo/pokemon/093.png    Haunter   0.1 kg
# 139  http://www.serebii.net/pokemongo/pokemon/140.png     Kabuto  11.5 kg
#
#                               weaknesses           candy
# 8                      [Electric, Grass]  Squirtle Candy
# 92        [Ground, Psychic, Ghost, Dark]    Gastly Candy
# 139  [Electric, Grass, Fighting, Ground]    Kabuto Candy

# %% [markdown]
# Question 7 -
# Using the data from Question 4, write code to analyze the data and answer the following questions Note -
# 1. Draw plots to demonstrate the analysis for the following questions for better visualizations
# 2. Write code comments wherever required for code understanding

# %%
import pandas as pd
import requests
url = "https://data.nasa.gov/resource/y77d-th95.json" 
response = requests.get(url)
data = response.json()
df=pd.DataFrame(data)
df
# Out:
#           name     id nametype               recclass    mass  fall  \
# 0       Aachen      1    Valid                     L5      21  Fell
# 1       Aarhus      2    Valid                     H6     720  Fell
# 2         Abee      6    Valid                    EH4  107000  Fell
# 3     Acapulco     10    Valid            Acapulcoite    1914  Fell
# 4      Achiras    370    Valid                     L6     780  Fell
# ..         ...    ...      ...                    ...     ...   ...
# 995   Tirupati  24009    Valid                     H6     230  Fell
# 996    Tissint  54823    Valid  Martian (shergottite)    7000  Fell
# 997      Tjabe  24011    Valid                     H6   20000  Fell
# 998   Tjerebon  24012    Valid                     L5   16500  Fell
# 999  Tomakovka  24019    Valid                    LL6     600  Fell
#
#                         year      reclat      reclong  \
# 0    1880-01-01T00:00:00.000   50.775000     6.083330
# 1    1951-01-01T00:00:00.000   56.183330    10.233330
# 2    1952-01-01T00:00:00.000   54.216670  -113.000000
# 3    1976-01-01T00:00:00.000   16.883330   -99.900000
# 4    1902-01-01T00:00:00.000  -33.166670   -64.950000
# ..                       ...         ...          ...
# 995  1934-01-01T00:00:00.000   13.633330    79.416670
# 996  2011-01-01T00:00:00.000   29.481950    -7.611230
# 997  1869-01-01T00:00:00.000   -7.083330   111.533330
# 998  1922-01-01T00:00:00.000   -6.666670   106.583330
# 999  1905-01-01T00:00:00.000   47.850000    34.766670
#
#                                            geolocation  \
# 0    {'type': 'Point', 'coordinates': [6.08333, 50....
# 1    {'type': 'Point', 'coordinates': [10.23333, 56...
# 2    {'type': 'Point', 'coordinates': [-113, 54.216...
# 3    {'type': 'Point', 'coordinates': [-99.9, 16.88...
# 4    {'type': 'Point', 'coordinates': [-64.95, -33....
# ..                                                 ...
# 995  {'type': 'Point', 'coordinates': [79.41667, 13...
# 996  {'type': 'Point', 'coordinates': [-7.61123, 29...
# 997  {'type': 'Point', 'coordinates': [111.53333, -...
# 998  {'type': 'Point', 'coordinates': [106.58333, -...
# 999  {'type': 'Point', 'coordinates': [34.76667, 47...
#
#     :@computed_region_cbhk_fwbd :@computed_region_nnqa_25f4
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
# ..                          ...                         ...
# 995                         NaN                         NaN
# 996                         NaN                         NaN
# 997                         NaN                         NaN
# 998                         NaN                         NaN
# 999                         NaN                         NaN
#
# [1000 rows x 12 columns]

# %% [markdown]
# Insights to be drawn -
# ● Get all the Earth meteorites that fell before the year 2000
# ● Get all the earth meteorites co-ordinates who fell before the year 1970
# ● Assuming that the mass of the earth meteorites was in kg, get all those whose mass was more
# than 10000kg

# %%
#Q.1
df['year_extracted']=df['year'].str[:4]

df[(df['fall'] == 'Fell') & (df['year_extracted']<'2000')]
# Out:
#           name     id nametype     recclass    mass  fall  \
# 0       Aachen      1    Valid           L5      21  Fell
# 1       Aarhus      2    Valid           H6     720  Fell
# 2         Abee      6    Valid          EH4  107000  Fell
# 3     Acapulco     10    Valid  Acapulcoite    1914  Fell
# 4      Achiras    370    Valid           L6     780  Fell
# ..         ...    ...      ...          ...     ...   ...
# 994   Timochin  24004    Valid           H5   65500  Fell
# 995   Tirupati  24009    Valid           H6     230  Fell
# 997      Tjabe  24011    Valid           H6   20000  Fell
# 998   Tjerebon  24012    Valid           L5   16500  Fell
# 999  Tomakovka  24019    Valid          LL6     600  Fell
#
#                         year      reclat      reclong  \
# 0    1880-01-01T00:00:00.000   50.775000     6.083330
# 1    1951-01-01T00:00:00.000   56.183330    10.233330
# 2    1952-01-01T00:00:00.000   54.216670  -113.000000
# 3    1976-01-01T00:00:00.000   16.883330   -99.900000
# 4    1902-01-01T00:00:00.000  -33.166670   -64.950000
# ..                       ...         ...          ...
# 994  1807-01-01T00:00:00.000   54.500000    35.200000
# 995  1934-01-01T00:00:00.000   13.633330    79.416670
# 997  1869-01-01T00:00:00.000   -7.083330   111.533330
# 998  1922-01-01T00:00:00.000   -6.666670   106.583330
# 999  1905-01-01T00:00:00.000   47.850000    34.766670
#
#                                            geolocation  \
# 0    {'type': 'Point', 'coordinates': [6.08333, 50....
# 1    {'type': 'Point', 'coordinates': [10.23333, 56...
# 2    {'type': 'Point', 'coordinates': [-113, 54.216...
# 3    {'type': 'Point', 'coordinates': [-99.9, 16.88...
# 4    {'type': 'Point', 'coordinates': [-64.95, -33....
# ..                                                 ...
# 994     {'type': 'Point', 'coordinates': [35.2, 54.5]}
# 995  {'type': 'Point', 'coordinates': [79.41667, 13...
# 997  {'type': 'Point', 'coordinates': [111.53333, -...
# 998  {'type': 'Point', 'coordinates': [106.58333, -...
# 999  {'type': 'Point', 'coordinates': [34.76667, 47...
#
#     :@computed_region_cbhk_fwbd :@computed_region_nnqa_25f4 year_extracted
# 0                           NaN                         NaN           1880
# 1                           NaN                         NaN           1951
# 2                           NaN                         NaN           1952
# 3                           NaN                         NaN           1976
# 4                           NaN                         NaN           1902
# ..                          ...                         ...            ...
# 994                         NaN                         NaN           1807
# 995                         NaN                         NaN           1934
# 997                         NaN                         NaN           1869
# 998                         NaN                         NaN           1922
# 999                         NaN                         NaN           1905
#
# [928 rows x 13 columns]

# %%
#Q.2
df['year_extracted']=df['year'].str[:4]

df[(df['fall'] == 'Fell') & (df['year_extracted']<'1970')]
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\2194802311.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year_extracted']=df['year'].str[:4]
#           name     id nametype recclass    mass  fall  \
# 0       Aachen      1    Valid       L5      21  Fell
# 1       Aarhus      2    Valid       H6     720  Fell
# 2         Abee      6    Valid      EH4  107000  Fell
# 4      Achiras    370    Valid       L6     780  Fell
# 5     Adhi Kot    379    Valid      EH4    4239  Fell
# ..         ...    ...      ...      ...     ...   ...
# 994   Timochin  24004    Valid       H5   65500  Fell
# 995   Tirupati  24009    Valid       H6     230  Fell
# 997      Tjabe  24011    Valid       H6   20000  Fell
# 998   Tjerebon  24012    Valid       L5   16500  Fell
# 999  Tomakovka  24019    Valid      LL6     600  Fell
#
#                         year      reclat      reclong  \
# 0    1880-01-01T00:00:00.000   50.775000     6.083330
# 1    1951-01-01T00:00:00.000   56.183330    10.233330
# 2    1952-01-01T00:00:00.000   54.216670  -113.000000
# 4    1902-01-01T00:00:00.000  -33.166670   -64.950000
# 5    1919-01-01T00:00:00.000   32.100000    71.800000
# ..                       ...         ...          ...
# 994  1807-01-01T00:00:00.000   54.500000    35.200000
# 995  1934-01-01T00:00:00.000   13.633330    79.416670
# 997  1869-01-01T00:00:00.000   -7.083330   111.533330
# 998  1922-01-01T00:00:00.000   -6.666670   106.583330
# 999  1905-01-01T00:00:00.000   47.850000    34.766670
#
#                                            geolocation  \
# 0    {'type': 'Point', 'coordinates': [6.08333, 50....
# 1    {'type': 'Point', 'coordinates': [10.23333, 56...
# 2    {'type': 'Point', 'coordinates': [-113, 54.216...
# 4    {'type': 'Point', 'coordinates': [-64.95, -33....
# 5       {'type': 'Point', 'coordinates': [71.8, 32.1]}
# ..                                                 ...
# 994     {'type': 'Point', 'coordinates': [35.2, 54.5]}
# 995  {'type': 'Point', 'coordinates': [79.41667, 13...
# 997  {'type': 'Point', 'coordinates': [111.53333, -...
# 998  {'type': 'Point', 'coordinates': [106.58333, -...
# 999  {'type': 'Point', 'coordinates': [34.76667, 47...
#
#     :@computed_region_cbhk_fwbd :@computed_region_nnqa_25f4 year_extracted
# 0                           NaN                         NaN           1880
# 1                           NaN                         NaN           1951
# 2                           NaN                         NaN           1952
# 4                           NaN                         NaN           1902
# 5                           NaN                         NaN           1919
# ..                          ...                         ...            ...
# 994                         NaN                         NaN           1807
# 995                         NaN                         NaN           1934
# 997                         NaN                         NaN           1869
# 998                         NaN                         NaN           1922
# 999                         NaN                         NaN           1905
#
# [779 rows x 13 columns]

# %%
#Q.3
df['mass'] = df['mass'].astype(float)

df[df['mass']>10000]
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14728\2109770787.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['mass'] = df['mass'].astype(float)
#            name     id nametype   recclass      mass  fall  \
# 2          Abee      6    Valid        EH4  107000.0  Fell
# 7          Agen    392    Valid         H5   30000.0  Fell
# 11          Aïr    424    Valid         L6   24000.0  Fell
# 16      Akyumak    433    Valid  Iron, IVA   50000.0  Fell
# 27   Alfianello    466    Valid         L6  228000.0  Fell
# ..          ...    ...      ...        ...       ...   ...
# 991   Tieschitz  23989    Valid     H/L3.6   28000.0  Fell
# 992      Tilden  23998    Valid         L6   74800.0  Fell
# 994    Timochin  24004    Valid         H5   65500.0  Fell
# 997       Tjabe  24011    Valid         H6   20000.0  Fell
# 998    Tjerebon  24012    Valid         L5   16500.0  Fell
#
#                         year     reclat      reclong  \
# 2    1952-01-01T00:00:00.000  54.216670  -113.000000
# 7    1814-01-01T00:00:00.000  44.216670     0.616670
# 11   1925-01-01T00:00:00.000  19.083330     8.383330
# 16   1981-01-01T00:00:00.000  39.916670    42.816670
# 27   1883-01-01T00:00:00.000  45.266670    10.150000
# ..                       ...        ...          ...
# 991  1878-01-01T00:00:00.000  49.600000    17.116670
# 992  1927-01-01T00:00:00.000  38.200000   -89.683330
# 994  1807-01-01T00:00:00.000  54.500000    35.200000
# 997  1869-01-01T00:00:00.000  -7.083330   111.533330
# 998  1922-01-01T00:00:00.000  -6.666670   106.583330
#
#                                            geolocation  \
# 2    {'type': 'Point', 'coordinates': [-113, 54.216...
# 7    {'type': 'Point', 'coordinates': [0.61667, 44....
# 11   {'type': 'Point', 'coordinates': [8.38333, 19....
# 16   {'type': 'Point', 'coordinates': [42.81667, 39...
# 27   {'type': 'Point', 'coordinates': [10.15, 45.26...
# ..                                                 ...
# 991  {'type': 'Point', 'coordinates': [17.11667, 49...
# 992  {'type': 'Point', 'coordinates': [-89.68333, 3...
# 994     {'type': 'Point', 'coordinates': [35.2, 54.5]}
# 997  {'type': 'Point', 'coordinates': [111.53333, -...
# 998  {'type': 'Point', 'coordinates': [106.58333, -...
#
#     :@computed_region_cbhk_fwbd :@computed_region_nnqa_25f4 year_extracted
# 2                           NaN                         NaN           1952
# 7                           NaN                         NaN           1814
# 11                          NaN                         NaN           1925
# 16                          NaN                         NaN           1981
# 27                          NaN                         NaN           1883
# ..                          ...                         ...            ...
# 991                         NaN                         NaN           1878
# 992                          34                        1762           1927
# 994                         NaN                         NaN           1807
# 997                         NaN                         NaN           1869
# 998                         NaN                         NaN           1922
#
# [242 rows x 13 columns]

# %% [markdown]
# Question 8 -
# Using the data from Question 5, write code the analyze the data and answer the following questions Note -
# 1. Draw plots to demonstrate the analysis for the following questions and better visualizations
# 2. Write code comments wherever required for code understanding

# %%
def api_to_csv(api_url):
    # Fetch the data from the API
    response = requests.get(api_url)
    data = response.json()

    # Extract episode details
    episodes = data["_embedded"]["episodes"]

    # Convert episode data to DataFrame
    df = pd.DataFrame(episodes)

    df.to_csv("Output.csv", index=False)

# %%
api_url = "http://api.tvmaze.com/singlesearch/shows?q=westworld&embed=episodes"
api_to_csv(api_url)
df = pd.read_csv("Output.csv")
df.head()
# Out:
#        id                                                url  \
# 0  869671  https://www.tvmaze.com/episodes/869671/westwor...
# 1  911201  https://www.tvmaze.com/episodes/911201/westwor...
# 2  911204  https://www.tvmaze.com/episodes/911204/westwor...
# 3  911205  https://www.tvmaze.com/episodes/911205/westwor...
# 4  927174  https://www.tvmaze.com/episodes/927174/westwor...
#
#                 name  season  number     type     airdate airtime  \
# 0       The Original       1       1  regular  2016-10-02   21:00
# 1           Chestnut       1       2  regular  2016-10-09   21:00
# 2          The Stray       1       3  regular  2016-10-16   21:00
# 3  Dissonance Theory       1       4  regular  2016-10-23   21:00
# 4        Contrapasso       1       5  regular  2016-10-30   21:00
#
#                     airstamp  runtime            rating  \
# 0  2016-10-03T01:00:00+00:00       68    {'average': 8}
# 1  2016-10-10T01:00:00+00:00       60  {'average': 7.7}
# 2  2016-10-17T01:00:00+00:00       60  {'average': 7.6}
# 3  2016-10-24T01:00:00+00:00       60  {'average': 7.9}
# 4  2016-10-31T01:00:00+00:00       60    {'average': 8}
#
#                                                image  \
# 0  {'medium': 'https://static.tvmaze.com/uploads/...
# 1  {'medium': 'https://static.tvmaze.com/uploads/...
# 2  {'medium': 'https://static.tvmaze.com/uploads/...
# 3  {'medium': 'https://static.tvmaze.com/uploads/...
# 4  {'medium': 'https://static.tvmaze.com/uploads/...
#
#                                              summary  \
# 0  <p>A woman named Dolores is a free spirit in t...
# 1  <p>Bernard suspects that someone is sabotaging...
# 2  <p>Bernard continues to investigate Dolores' s...
# 3  <p>While Dolores joins William and Logan on th...
# 4  <p>Dolores takes the first step on her path of...
#
#                                               _links
# 0  {'self': {'href': 'https://api.tvmaze.com/epis...
# 1  {'self': {'href': 'https://api.tvmaze.com/epis...
# 2  {'self': {'href': 'https://api.tvmaze.com/epis...
# 3  {'self': {'href': 'https://api.tvmaze.com/epis...
# 4  {'self': {'href': 'https://api.tvmaze.com/epis...

# %% [markdown]
# ● Get all the overall ratings for each season and using plots compare the ratings for all the
# seasons, like season 1 ratings, season 2, and so on.
# ● Get all the episode names, whose average rating is more than 8 for every season
# ● Get all the episode names that aired before May 2019
# ● Get the episode name from each season with the highest and lowest rating
# ● Get the summary for the most popular ( ratings ) episode in every season

# %%
#Q.1
import ast
df["rating"] = df["rating"].apply(lambda x: ast.literal_eval(x)['average'] if isinstance(x, str) else x)


season_ratings = df.groupby("season")["rating"].mean()
season_ratings.plot(kind="bar", xlabel="Season", ylabel="Rating", title="Ratings by Season")
plt.show()

# %%
#Q.2
df["rating"] = df["rating"].apply(lambda x: ast.literal_eval(x)['average']  if isinstance(x, str) else x)
df['name'][df["rating"]>8.0]
# Out:
# 6                 Trompe L'Oeil
# 8     The Well-Tempered Clavier
# 9            The Bicameral Mind
# 17                      Kiksuya
# 18              Vanishing Point
# 19                The Passenger
# Name: name, dtype: object

# %%
#Q.3
df['year']=df['airdate'].apply(lambda x : int(x.split("-")[0]))
df['name'][df['year']>2019]
# Out:
# 20            Parce Domine
# 21         The Winter Line
# 22    The Absence of Field
# 23    The Mother of Exiles
# 24                   Genre
# 25             Decoherence
# 26             Passed Pawn
# 27           Crisis Theory
# 28            The Auguries
# 29       Well Enough Alone
# 30           Années Folles
# 31         Generation Loss
# 32                Zhuangzi
# 33                Fidelity
# 34                Metanoia
# 35          Que Será, Será
# Name: name, dtype: object

# %%
#Q.4
df["rating"] = df["rating"].astype(float)
x=df['rating'].min()
y=df['rating'].max()
print("max rating",y,'------',"min rating",x)
# Out:
# max rating 8.7 ------ min rating 7.1

# %%
#Q.5
df["popular"] = pd.Series(list(dict(df.groupby(["name"])["rating"].sum() > 8).values()))
df.loc[df["popular"] == True]["name"]
# Out:
# 11                 Reunion
# 22    The Absence of Field
# 25             Decoherence
# 28            The Auguries
# 31         Generation Loss
# 32                Zhuangzi
# Name: name, dtype: object

# %% [markdown]
# #Q.9-
# Question 9 -
# Write a program to read the data from the following link, perform data analysis and answer the following
# questions
# Note -
# 1. Write code comments wherever required for code understanding
# Link - https://data.wa.gov/api/views/f6w7-q2d2/rows.csv?accessType=DOWNLOAD

# %%
df=pd.read_csv(r"Electric_Vehicle_Population_Data.csv")
df.head()
# Out:
#    VIN (1-10)    County     City State  Postal Code  Model Year    Make  \
# 0  5YJXCAE26J    Yakima   Yakima    WA      98908.0        2018   TESLA
# 1  JHMZC5F37M    Kitsap  Poulsbo    WA      98370.0        2021   HONDA
# 2  5YJ3E1EB0K      King  Seattle    WA      98199.0        2019   TESLA
# 3  1N4AZ0CP5D      King  Seattle    WA      98119.0        2013  NISSAN
# 4  5YJSA1E21H  Thurston    Lacey    WA      98516.0        2017   TESLA
#
#      Model                   Electric Vehicle Type  \
# 0  MODEL X          Battery Electric Vehicle (BEV)
# 1  CLARITY  Plug-in Hybrid Electric Vehicle (PHEV)
# 2  MODEL 3          Battery Electric Vehicle (BEV)
# 3     LEAF          Battery Electric Vehicle (BEV)
# 4  MODEL S          Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible             238
# 1           Clean Alternative Fuel Vehicle Eligible              47
# 2           Clean Alternative Fuel Vehicle Eligible             220
# 3           Clean Alternative Fuel Vehicle Eligible              75
# 4           Clean Alternative Fuel Vehicle Eligible             210
#
#    Base MSRP  Legislative District  DOL Vehicle ID  \
# 0          0                  14.0       141151601
# 1          0                  23.0       171566447
# 2          0                  36.0         9426525
# 3          0                  36.0       211807760
# 4          0                  22.0       185810306
#
#               Vehicle Location                              Electric Utility  \
# 0  POINT (-120.56916 46.58514)                                    PACIFICORP
# 1  POINT (-122.64681 47.73689)                        PUGET SOUND ENERGY INC
# 2  POINT (-122.40092 47.65908)  CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)
# 3   POINT (-122.3684 47.64586)  CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)
# 4  POINT (-122.75379 47.06316)                        PUGET SOUND ENERGY INC
#
#    2020 Census Tract
# 0       5.307700e+10
# 1       5.303509e+10
# 2       5.303301e+10
# 3       5.303301e+10
# 4       5.306701e+10

# %% [markdown]
# Insights to be drawn -
# ● Get all the cars and their types that do not qualify for clean alternative fuel vehicle
# ● Get all TESLA cars with the model year, and model type made in Bothell City.
# ● Get all the cars that have an electric range of more than 100, and were made after
# 2015
# ● Draw plots to show the distribution between city and electric vehicle type

# %%
#Q.1
car=df[(df["Clean Alternative Fuel Vehicle (CAFV) Eligibility"]) != "Clean Alternative Fuel Vehicle Eligible"]
car
# Out:
#         VIN (1-10)    County        City State  Postal Code  Model Year  \
# 6       3FA6P0PU1G  Thurston    Tumwater    WA      98501.0        2016
# 7       WA1F2AFY8P  Thurston       Lacey    WA      98516.0        2023
# 8       1FADP5CU0E  Thurston   Rochester    WA      98579.0        2014
# 11      7SAYGDEF4N    Yakima      Yakima    WA      98908.0        2022
# 14      1FADP5FU4H  Thurston       Lacey    WA      98513.0        2017
# ...            ...       ...         ...   ...          ...         ...
# 130437  WBA13AG06M  Thurston     Olympia    WA      98501.0        2021
# 130438  7SAYGDEE6P    Pierce  Gig Harbor    WA      98335.0        2023
# 130439  1N4BZ1CV7N    Pierce      Tacoma    WA      98408.0        2022
# 130440  5YJYGDEE8M      King     Seattle    WA      98109.0        2021
# 130442  5YJ3E1EA5M    Pierce    Puyallup    WA      98375.0        2021
#
#           Make    Model                   Electric Vehicle Type  \
# 6         FORD   FUSION  Plug-in Hybrid Electric Vehicle (PHEV)
# 7         AUDI     Q5 E  Plug-in Hybrid Electric Vehicle (PHEV)
# 8         FORD    C-MAX  Plug-in Hybrid Electric Vehicle (PHEV)
# 11       TESLA  MODEL Y          Battery Electric Vehicle (BEV)
# 14        FORD    C-MAX  Plug-in Hybrid Electric Vehicle (PHEV)
# ...        ...      ...                                     ...
# 130437     BMW     530E  Plug-in Hybrid Electric Vehicle (PHEV)
# 130438   TESLA  MODEL Y          Battery Electric Vehicle (BEV)
# 130439  NISSAN     LEAF          Battery Electric Vehicle (BEV)
# 130440   TESLA  MODEL Y          Battery Electric Vehicle (BEV)
# 130442   TESLA  MODEL 3          Battery Electric Vehicle (BEV)
#
#         Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 6                   Not eligible due to low battery range              19
# 7                   Not eligible due to low battery range              23
# 8                   Not eligible due to low battery range              19
# 11      Eligibility unknown as battery range has not b...               0
# 14                  Not eligible due to low battery range              20
# ...                                                   ...             ...
# 130437              Not eligible due to low battery range              21
# 130438  Eligibility unknown as battery range has not b...               0
# 130439  Eligibility unknown as battery range has not b...               0
# 130440  Eligibility unknown as battery range has not b...               0
# 130442  Eligibility unknown as battery range has not b...               0
#
#         Base MSRP  Legislative District  DOL Vehicle ID  \
# 6               0                  22.0       347508836
# 7               0                  22.0       227213871
# 8               0                  20.0       229811151
# 11              0                  14.0       187486883
# 14              0                  22.0       139887513
# ...           ...                   ...             ...
# 130437          0                  22.0       196559310
# 130438          0                  26.0       231134102
# 130439          0                  29.0       185810943
# 130440          0                  36.0       176542418
# 130442          0                   2.0       180473639
#
#                                       Vehicle Location  \
# 6                          POINT (-122.89166 47.03956)
# 7                          POINT (-122.75379 47.06316)
# 8                          POINT (-123.08743 46.82175)
# 11                         POINT (-120.56916 46.58514)
# 14       POINT (-122.81754499999994 46.98876000000007)
# ...                                                ...
# 130437                     POINT (-122.89166 47.03956)
# 130438   POINT (-122.58354539999999 47.32344880000005)
# 130439  POINT (-122.43810499999995 47.203220000000044)
# 130440                     POINT (-122.35022 47.63824)
# 130442                      POINT (-122.30116 47.1165)
#
#                                          Electric Utility  2020 Census Tract
# 6                                  PUGET SOUND ENERGY INC       5.306701e+10
# 7                                  PUGET SOUND ENERGY INC       5.306701e+10
# 8                                  PUGET SOUND ENERGY INC       5.306701e+10
# 11                                             PACIFICORP       5.307700e+10
# 14                                 PUGET SOUND ENERGY INC       5.306701e+10
# ...                                                   ...                ...
# 130437                             PUGET SOUND ENERGY INC       5.306701e+10
# 130438  BONNEVILLE POWER ADMINISTRATION||CITY OF TACOM...       5.305307e+10
# 130439  BONNEVILLE POWER ADMINISTRATION||CITY OF TACOM...       5.305306e+10
# 130440       CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303301e+10
# 130442  BONNEVILLE POWER ADMINISTRATION||CITY OF TACOM...       5.305307e+10
#
# [69892 rows x 17 columns]

# %%
#Q.2
car= df[(df["Make"] == "TESLA") & (df["City"] == "Bothell")]
car
# Out:
#         VIN (1-10)     County     City State  Postal Code  Model Year   Make  \
# 39      5YJ3E1EA6L  Snohomish  Bothell    WA      98012.0        2020  TESLA
# 217     5YJ3E1EB9N       King  Bothell    WA      98011.0        2022  TESLA
# 218     7SAYGDEEXN  Snohomish  Bothell    WA      98012.0        2022  TESLA
# 222     5YJ3E1EB6J       King  Bothell    WA      98011.0        2018  TESLA
# 292     5YJXCBE40H       King  Bothell    WA      98011.0        2017  TESLA
# ...            ...        ...      ...   ...          ...         ...    ...
# 129778  5YJ3E1EB3K  Snohomish  Bothell    WA      98012.0        2019  TESLA
# 129954  5YJ3E1EB3M  Snohomish  Bothell    WA      98021.0        2021  TESLA
# 129976  5YJSA1S10E  Snohomish  Bothell    WA      98021.0        2014  TESLA
# 130295  5YJ3E1EA8N  Snohomish  Bothell    WA      98021.0        2022  TESLA
# 130392  5YJ3E1EA9J       King  Bothell    WA      98011.0        2018  TESLA
#
#           Model           Electric Vehicle Type  \
# 39      MODEL 3  Battery Electric Vehicle (BEV)
# 217     MODEL 3  Battery Electric Vehicle (BEV)
# 218     MODEL Y  Battery Electric Vehicle (BEV)
# 222     MODEL 3  Battery Electric Vehicle (BEV)
# 292     MODEL X  Battery Electric Vehicle (BEV)
# ...         ...                             ...
# 129778  MODEL 3  Battery Electric Vehicle (BEV)
# 129954  MODEL 3  Battery Electric Vehicle (BEV)
# 129976  MODEL S  Battery Electric Vehicle (BEV)
# 130295  MODEL 3  Battery Electric Vehicle (BEV)
# 130392  MODEL 3  Battery Electric Vehicle (BEV)
#
#         Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 39                Clean Alternative Fuel Vehicle Eligible             266
# 217     Eligibility unknown as battery range has not b...               0
# 218     Eligibility unknown as battery range has not b...               0
# 222               Clean Alternative Fuel Vehicle Eligible             215
# 292               Clean Alternative Fuel Vehicle Eligible             200
# ...                                                   ...             ...
# 129778            Clean Alternative Fuel Vehicle Eligible             220
# 129954  Eligibility unknown as battery range has not b...               0
# 129976            Clean Alternative Fuel Vehicle Eligible             208
# 130295  Eligibility unknown as battery range has not b...               0
# 130392            Clean Alternative Fuel Vehicle Eligible             215
#
#         Base MSRP  Legislative District  DOL Vehicle ID  \
# 39              0                  21.0       127506886
# 217             0                   1.0       195097472
# 218             0                   1.0       205456996
# 222             0                   1.0       200733662
# 292             0                   1.0       229900653
# ...           ...                   ...             ...
# 129778          0                   1.0       176326356
# 129954          0                   1.0       137418676
# 129976      69900                   1.0       171609553
# 130295          0                   1.0       211349001
# 130392          0                   1.0       195609585
#
#                    Vehicle Location  \
# 39      POINT (-122.21061 47.83448)
# 217     POINT (-122.20563 47.76144)
# 218     POINT (-122.21061 47.83448)
# 222     POINT (-122.20563 47.76144)
# 292     POINT (-122.20563 47.76144)
# ...                             ...
# 129778  POINT (-122.21061 47.83448)
# 129954   POINT (-122.18384 47.8031)
# 129976   POINT (-122.18384 47.8031)
# 130295   POINT (-122.18384 47.8031)
# 130392  POINT (-122.20563 47.76144)
#
#                                      Electric Utility  2020 Census Tract
# 39                             PUGET SOUND ENERGY INC       5.306105e+10
# 217     PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303302e+10
# 218                            PUGET SOUND ENERGY INC       5.306105e+10
# 222     PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303302e+10
# 292     PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303302e+10
# ...                                               ...                ...
# 129778                         PUGET SOUND ENERGY INC       5.306105e+10
# 129954                         PUGET SOUND ENERGY INC       5.306105e+10
# 129976                         PUGET SOUND ENERGY INC       5.306105e+10
# 130295                         PUGET SOUND ENERGY INC       5.306105e+10
# 130392  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303302e+10
#
# [2407 rows x 17 columns]

# %%
#Q.3
df[(df["Electric Range"]> 100) & (df["Model Year"]>2015)]
# Out:
#         VIN (1-10)    County           City State  Postal Code  Model Year  \
# 0       5YJXCAE26J    Yakima         Yakima    WA      98908.0        2018
# 2       5YJ3E1EB0K      King        Seattle    WA      98199.0        2019
# 4       5YJSA1E21H  Thurston          Lacey    WA      98516.0        2017
# 12      5YJ3E1EC7L  Thurston          Lacey    WA      98503.0        2020
# 13      5YJ3E1EB2L  Thurston        Olympia    WA      98516.0        2020
# ...            ...       ...            ...   ...          ...         ...
# 130417  5YJYGDEE5L    Pierce         Tacoma    WA      98444.0        2020
# 130428  1N4AZ1CP0J   Clallam         Sequim    WA      98382.0        2018
# 130432  5YJYGDEEXL      King         Vashon    WA      98070.0        2020
# 130436  5YJ3E1EB0J   Whatcom         Blaine    WA      98230.0        2018
# 130441  5YJXCBE22L    Island  Camano Island    WA      98282.0        2020
#
#           Make    Model           Electric Vehicle Type  \
# 0        TESLA  MODEL X  Battery Electric Vehicle (BEV)
# 2        TESLA  MODEL 3  Battery Electric Vehicle (BEV)
# 4        TESLA  MODEL S  Battery Electric Vehicle (BEV)
# 12       TESLA  MODEL 3  Battery Electric Vehicle (BEV)
# 13       TESLA  MODEL 3  Battery Electric Vehicle (BEV)
# ...        ...      ...                             ...
# 130417   TESLA  MODEL Y  Battery Electric Vehicle (BEV)
# 130428  NISSAN     LEAF  Battery Electric Vehicle (BEV)
# 130432   TESLA  MODEL Y  Battery Electric Vehicle (BEV)
# 130436   TESLA  MODEL 3  Battery Electric Vehicle (BEV)
# 130441   TESLA  MODEL X  Battery Electric Vehicle (BEV)
#
#        Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0                Clean Alternative Fuel Vehicle Eligible             238
# 2                Clean Alternative Fuel Vehicle Eligible             220
# 4                Clean Alternative Fuel Vehicle Eligible             210
# 12               Clean Alternative Fuel Vehicle Eligible             308
# 13               Clean Alternative Fuel Vehicle Eligible             322
# ...                                                  ...             ...
# 130417           Clean Alternative Fuel Vehicle Eligible             291
# 130428           Clean Alternative Fuel Vehicle Eligible             151
# 130432           Clean Alternative Fuel Vehicle Eligible             291
# 130436           Clean Alternative Fuel Vehicle Eligible             215
# 130441           Clean Alternative Fuel Vehicle Eligible             293
#
#         Base MSRP  Legislative District  DOL Vehicle ID  \
# 0               0                  14.0       141151601
# 2               0                  36.0         9426525
# 4               0                  22.0       185810306
# 12              0                  22.0         2135486
# 13              0                  22.0       124645363
# ...           ...                   ...             ...
# 130417          0                  29.0       112591538
# 130428          0                  24.0       290405174
# 130432          0                  34.0       112734723
# 130436          0                  42.0       103521302
# 130441          0                  10.0       102834938
#
#                                      Vehicle Location  \
# 0                         POINT (-120.56916 46.58514)
# 2                         POINT (-122.40092 47.65908)
# 4                         POINT (-122.75379 47.06316)
# 12                        POINT (-122.82324 47.04437)
# 13                        POINT (-122.75379 47.06316)
# ...                                               ...
# 130417                    POINT (-122.46495 47.16778)
# 130428  POINT (-123.09968999999995 48.08137000000005)
# 130432                     POINT (-122.4573 47.44929)
# 130436                    POINT (-122.74888 48.99404)
# 130441                    POINT (-122.40049 48.23986)
#
#                                          Electric Utility  2020 Census Tract
# 0                                              PACIFICORP       5.307700e+10
# 2            CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303301e+10
# 4                                  PUGET SOUND ENERGY INC       5.306701e+10
# 12                                 PUGET SOUND ENERGY INC       5.306701e+10
# 13                                 PUGET SOUND ENERGY INC       5.306701e+10
# ...                                                   ...                ...
# 130417  BONNEVILLE POWER ADMINISTRATION||CITY OF TACOM...       5.305306e+10
# 130428  BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF C...       5.300900e+10
# 130432      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 130436  PUGET SOUND ENERGY INC||PUD NO 1 OF WHATCOM CO...       5.307301e+10
# 130441  BONNEVILLE POWER ADMINISTRATION||PUD 1 OF SNOH...       5.302997e+10
#
# [34066 rows x 17 columns]

# %%
#Q.4
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
top_20 = df.groupby("City")["Electric Vehicle Type"].count().sort_values(ascending=False)[:20]
x = list(dict(top_20).keys())
y = list(dict(top_20).values())
fig, ax = plt.subplots(figsize=(20,5))
sns.barplot(x=x, y=y)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Question 10 -
# Write a program to count the number of verbs, nouns, pronouns, and adjectives in a given particular phrase or
# paragraph, and return their respective count as a dictionary.

# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# True

# %%
def count_pos(text):
    tokens = word_tokenize(text)
    tags = pos_tag(tokens)
    counts = {"verb": 0, "noun": 0, "pronoun": 0, "adjective": 0}
    for tag in tags:
        pos = tag[1]
        if pos.startswith("V"):
            counts["verb"] += 1
        elif pos.startswith("N"):
            counts["noun"] += 1
        elif pos.startswith("PR"):
            counts["pronoun"] += 1
        elif pos.startswith("J"):
            counts["adjective"] += 1
    return counts

# %%
text = "Hello I'm Sharanya and I'm a Data Scientist"
counts = count_pos(text)
print(counts)
# Out:
# {'verb': 2, 'noun': 3, 'pronoun': 2, 'adjective': 1}
